# %%
# Dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\busra\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\busra\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\busra\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\busra\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
dataset = pd.read_csv("TweetData.csv")
dataset.head(10)
# Out:
#              Tweet Id        Date   Hour            User Name  \
# 0  723066388391157762  2016-04-21  08:30                  ZPR
# 1  723066384297672704  2016-04-21  08:30           Beep!Beep!
# 2  723066381751689216  2016-04-21  08:30              Annette
# 3  723066348201353216  2016-04-21  08:30         Dollie Henry
# 4  723066340953722880  2016-04-21  08:30       Cleo Bannister
# 5  723066335803019264  2016-04-21  08:30    Quintiles Careers
# 6  723066329918504960  2016-04-21  08:30         Rojas Wilmer
# 7  723066322528120832  2016-04-21  08:30            TubeMogul
# 8  723066311291592704  2016-04-21  08:30  Sheila Murray-Forde
# 9  723066307793588224  2016-04-21  08:30      Pickwick Papers
#
#           Nickname                                                Bio  \
# 0          ZPRSoho  22 straight talking PRs based in Soho sharing ...
# 1  BeepBeepTraffic  UK Traffic Alert App for iOS http://t.co/55H1q...
# 2  annetteand2dogs  Sociologist, (vintage) cyclist, dog lover, mus...
# ...

# %%
# Filter relevant columns
dataset1 = dataset.loc[ : , ('Tweet content','Latitude', 'Longitude', 'Country','Place (as appears on Bio)' ,'Tweet language (ISO 639-1)')]

# ... and rename them
dataset1.rename(columns={'Tweet content':'Text', 
                         'Tweet language (ISO 639-1)': 'Language',
                         'Place (as appears on Bio)': 'City'}, inplace=True)

# filter language to be english- only
dataset2 = dataset1[dataset1['Language'] == 'en']

# dropNA
dataset2.dropna()

dataset2.reset_index(drop=True,inplace=True)

# %%
dataset2['City'].head(10)
# Out:
# 0         London, England
# 1     Willenhall, England
# 2    Dublin City, Ireland
# 3         London, England
# 4     Manchester, England
# 5     Camden Town, London
# 6        Haworth, England
# 7          Eltham, London
# 8       Kilkenny, Ireland
# 9      Hillingdon, London
# Name: City, dtype: object

# %%
dataset2 = dataset2.dropna(subset=['City', 'Country'],axis=0)

# %%
dataset2.head(55)
# Out:
#                                                  Text   Latitude  Longitude  \
# 0   Talking to some great journos this morning all...  51.505185  -0.150128
# 1   Incident (Severe delay) M6 northbound between ...  52.615627  -2.029030
# 2   THIS: “@Colmogorman: Great piece by @amcteirna...  53.336995  -6.279686
# 3   A Little snippet from my #SundayJazzCongregati...  51.513451  -0.125331
# 4   If you're a #Pharmaceutical professional in #M...  53.480759  -2.242631
# 5   Our 2 day @Cadreon_IPG Summit kicks off in our...  51.515238  -0.127154
# 6   Remembering Charlotte Bronte on the 200th anni...  53.832276  -1.958013
# 7   "@christmas_cabin: @PickwickFabrics Hell Yeah!...  51.430730   0.070274
# 8   Wind 3.2 km/h ENE. Barometer 1023.30 mb, Risin...  52.733333  -7.183333
# 9   2 hours to kill (@ London @HeathrowAirport (LH...  51.469715  -0.459881
# 10  Heacham Weather:Temp=11.9C &amp; is Rising.Low...  52.908611   0.479167
# ...

# %%
dataset3 = dataset2['City']
london = dataset3.str.contains('London')
london[:5]
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: City, dtype: bool

# %%
dataset2['City'] = np.where(london, 'London',dataset3.str.replace('-', ' '))
# Out:
# <ipython-input-120-0a7f9d1b2ad3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset2['City'] = np.where(london, 'London',dataset3.str.replace('-', ' '))

# %%
dataset2['City'].head(800)
# Out:
# 0                     London
# 1        Willenhall, England
# 2       Dublin City, Ireland
# 3                     London
# 4                 Manchester
#                ...
# 805    South Dublin, Ireland
# 806                   London
# 807     Whitley Bay, England
# 809        Ormskirk, England
# 810          Yeovil, England
# Name: City, Length: 800, dtype: object

# %%
dataset4 = dataset2['City']
edinburgh = dataset4.str.contains('Edinburgh')
edinburgh[:8]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: City, dtype: bool

# %%
dataset2['City'] = np.where(edinburgh, 'Edinburgh',dataset4.str.replace('-', ' '))
# Out:
# <ipython-input-123-948c0746cb94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset2['City'] = np.where(edinburgh, 'Edinburgh',dataset4.str.replace('-', ' '))

# %%
dataset2['City'].head(40)
dataset2[dataset2['City']=='Edinburgh']
# Out:
#                                                      Text   Latitude  \
# 114     #hellostorm (@ Storm ID in Edinburgh) https://...  55.975023
# 192     Arriving to a fine weather in #edinburgh #scot...  55.949618
# 264                          @jwmadrid @Arsenal football?  55.941759
# 412     Become a tree. For those old enough to remembe...  55.940924
# 943     some bright colours to liven up your day #woll...  55.938380
# ...                                                   ...        ...
# 154162  〰🖼 Big little eggs 🖼〰 #asbestosreststop @ Edin...  55.945189
# 154338  Just posted a photo @ Calton Hill, Nelson Monu...  55.954597
# 154694  #ProjectMgmt #Job alert: Firewall Administrato...  55.953252
# 154739  I work in the #elephanthousecafé now because I...  55.947444
# 154810  'Micky, do you think I should go for a run?' -...  55.966609
#
#         Longitude Country       City Language
# 114     -3.166691      GB  Edinburgh       en
# ...

# %%
dataset5 = dataset2['City']
manchester = dataset5.str.contains('Manchester')
manchester[:8]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# Name: City, dtype: bool

# %%
dataset2['City'] = np.where(manchester, 'Manchester',dataset5.str.replace('-', ' '))
# Out:
# <ipython-input-126-2d4eaf2e2235>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset2['City'] = np.where(manchester, 'Manchester',dataset5.str.replace('-', ' '))

# %%
dataset2['City'].head(40)
dataset2[dataset2['City']=='Manchester']
# Out:
#                                                      Text   Latitude  \
# 4       If you're a #Pharmaceutical professional in #M...  53.480759
# 44      Join the Kellogg team! See our latest #Marketi...  53.480759
# 88      @TfLTravelAlerts is there a tube/workers strik...  53.474907
# 90      I'm at @WeAreDigitl in Manchester w/ @webdarre...  53.501591
# 94      #BusinessRocks (@ Manchester Central in Manche...  53.476247
# ...                                                   ...        ...
# 154709  What a show #animalcollective #Manchester #rit...  53.474334
# 154771  Today's Hairstyle of the Devil @ OxfamEmporium...  53.481979
# 154852  SCENTED// studio today.  There's a mountain of...  53.466700
# 154860                           I love my bed too much 🌈  53.441512
# 154913  Dah sampaiiii (@ Manchester International Airp...  53.362359
#
#         Longitude Country        City Language
# 4       -2.242631      GB  Manchester       en
# ...

# %%
dataset2.iloc[114]
# Out:
# Text         Somerleyton, 9a Sandycove Avenue West, Sand.. ...
# Latitude                                             53.286982
# Longitude                                            -6.115162
# Country                                                     IE
# City                           Dun Laoghaire Rathdown, Ireland
# Language                                                    en
# Name: 116, dtype: object

# %%
dataset2[dataset2['City']=='Edinburgh']
# Out:
#                                                      Text   Latitude  \
# 114     #hellostorm (@ Storm ID in Edinburgh) https://...  55.975023
# 192     Arriving to a fine weather in #edinburgh #scot...  55.949618
# 264                          @jwmadrid @Arsenal football?  55.941759
# 412     Become a tree. For those old enough to remembe...  55.940924
# 943     some bright colours to liven up your day #woll...  55.938380
# ...                                                   ...        ...
# 154162  〰🖼 Big little eggs 🖼〰 #asbestosreststop @ Edin...  55.945189
# 154338  Just posted a photo @ Calton Hill, Nelson Monu...  55.954597
# 154694  #ProjectMgmt #Job alert: Firewall Administrato...  55.953252
# 154739  I work in the #elephanthousecafé now because I...  55.947444
# 154810  'Micky, do you think I should go for a run?' -...  55.966609
#
#         Longitude Country       City Language
# 114     -3.166691      GB  Edinburgh       en
# ...

# %%
x=dataset2[dataset2['City'].str.contains("Manchester")==False]

# %%
x.head(88)
# Out:
#                                                  Text   Latitude  Longitude  \
# 0   Talking to some great journos this morning all...  51.505185  -0.150128
# 1   Incident (Severe delay) M6 northbound between ...  52.615627  -2.029030
# 2   THIS: “@Colmogorman: Great piece by @amcteirna...  53.336995  -6.279686
# 3   A Little snippet from my #SundayJazzCongregati...  51.513451  -0.125331
# 5   Our 2 day @Cadreon_IPG Summit kicks off in our...  51.515238  -0.127154
# ..                                                ...        ...        ...
# 87  Excellent performance in London has fallen and...  51.546923  -0.175388
# 89  'Twas goood ramen 😋\n Rich pork broth, super y...  51.512959  -0.132240
# 91  Its end of April and I am dying to swap this h...  51.500754  -0.055445
# 92  @mooseandjrock its the queens birthday but its...  53.487657  -1.357041
# 93  Bluebell in #highburypark #macro #igbest_macro...  52.413376  -1.904081
#
#    Country                               City Language
# ...

# %%
x2=dataset2.query("City=='London' or City=='Manchester' or City=='Edinburgh'")

# %%
x2.head(60)
# Out:
#                                                   Text   Latitude  Longitude  \
# 0    talking to some great journos this morning all...  51.505185  -0.150128
# 3    a little snippet from my  sundayjazzcongregati...  51.513451  -0.125331
# 4    if you're a  pharmaceutical professional in  m...  53.480759  -2.242631
# 5    our 2 day  summit kicks off in our new office ...  51.515238  -0.127154
# 7    "  hell yeah! x"\nlook at you      all posh on...  51.430730   0.070274
# 9    2 hours to kill (at london  (lhr) in hounslow,...  51.469715  -0.459881
# 12   when life gives you lemon choux with meringue ...  51.513302  -0.131348
# 13    egaylity    homophobia in morocco  gay or str...  51.619671   0.020313
# 14    egaylity    homophobia in morocco  gay or str...  51.619671   0.020313
# 30                 twin peaks 20 04 16 at rough trade   51.521085  -0.072385
# 42   pure's hannah booth  amp  peter horobin at las...  51.526224  -0.087952
# ...

# %%
x3 = x2[x2.isna().any(axis=1)]
print(x3)
# Out:
#                                                     Text   Latitude  \
# 10519  #destinationanywhere after a really long time ...  51.495495
# 10906  Good thing, I had set up twitter with my numbe...  51.495495
# 27282                @SuperShinkenRed Yeah it was great!  51.549550
# 27818  @DengroveAriel #ShortHair #Blonde #Selfie #Bor...  51.513514
# 28700  @SuperShinkenRed They were against Tamina and ...  51.513514
# 31924  #BetterCallSaul come on its been 2 season when...  51.513514
# 31964  #BetterCallSaul Mike's story is so much better...  51.513514
# 51976  Watch "Meg Myers - Lemon Eyes [Music Video]" o...  51.513514
# 82441  Do they still sell ladies jeans unripped at th...  51.549550
#
#        Longitude Country    City Language
# 10519        NaN      GB  London       en
# 10906        NaN      GB  London       en
# 27282        NaN      GB  London       en
# 27818        NaN      GB  London       en
# 28700        NaN      GB  London       en
# ...

# %%
# Keep cleaning dataframe 'cleaned_en_df' to keep text only (remove emojis, html etc..)
def standardize_text(dataset, text_field):
    dataset[text_field] = dataset[text_field].str.replace(r"http\S+", "")
    dataset[text_field] = dataset[text_field].str.replace(r"http", "")
    dataset[text_field] = dataset[text_field].str.replace(r"@\S+", "")
    dataset[text_field] = dataset[text_field].str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\_\n]", " ")
    dataset[text_field] = dataset[text_field].str.replace(r"@", "at")
    dataset[text_field] = dataset[text_field].str.lower()
    return df

tweets_df = standardize_text(x2, "Text")
tweets_df.head(10)
# Out:
# <ipython-input-158-1e4886f5977c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataset[text_field] = dataset[text_field].str.replace(r"http\S+", "")
# <ipython-input-158-1e4886f5977c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[text_field] = dataset[text_field].str.replace(r"http\S+", "")
# <ipython-input-158-1e4886f5977c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import re
tweets_df=x2

# %%
def remove_symbs(text):
    html = re.compile(r'[^\w]')
    return html.sub(r" ", text)

tweets_df["Text_Clean"] = tweets_df['Text'].map(lambda x: remove_symbs(x)) #1 --> #1
# Out:
# <ipython-input-172-8771977fcdb4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df["Text_Clean"] = tweets_df['Text'].map(lambda x: remove_symbs(x)) #1 --> #1

# %%
tweets_df
# Out:
#                                                      Text   Latitude  \
# 0       talking to some great journos this morning all...  51.505185
# 3       a little snippet from my  sundayjazzcongregati...  51.513451
# 4       if you're a  pharmaceutical professional in  m...  53.480759
# 5       our 2 day  summit kicks off in our new office ...  51.515238
# 7       "  hell yeah! x"\nlook at you      all posh on...  51.430730
# ...                                                   ...        ...
# 154885   frontroomfatloss\n\ntry this, another of our ...  51.449963
# 154888   london, england  hr  job  payroll specialist ...  51.507351
# 154889   earlyaction   still a big gap between rhetori...  51.516437
# 154902  the limitations and benefits of social media f...  51.501350
# 154913  dah sampaiiii (at manchester international air...  53.362359
#
#         Longitude Country        City Language  \
# 0       -0.150128      GB      London       en
# ...

# %%
# URL & HTML Removal
def remove_URL(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r"", text)

def remove_html(text):
    html = re.compile(r"<.*?>")
    return html.sub(r"", text)

# %%
tweets_df
# Out:
#                                                      Text   Latitude  \
# 0       talking to some great journos this morning all...  51.505185
# 3       a little snippet from my  sundayjazzcongregati...  51.513451
# 4       if you're a  pharmaceutical professional in  m...  53.480759
# 5       our 2 day  summit kicks off in our new office ...  51.515238
# 7       "  hell yeah! x"\nlook at you      all posh on...  51.430730
# ...                                                   ...        ...
# 154885   frontroomfatloss\n\ntry this, another of our ...  51.449963
# 154888   london, england  hr  job  payroll specialist ...  51.507351
# 154889   earlyaction   still a big gap between rhetori...  51.516437
# 154902  the limitations and benefits of social media f...  51.501350
# 154913  dah sampaiiii (at manchester international air...  53.362359
#
#         Longitude Country        City Language  \
# 0       -0.150128      GB      London       en
# ...

# %%
tweets_df.to_csv('deneme1.csv')

# %%
df46 = pd.read_csv ('C:/Users/busra/Ahoy/Jordan/datasets/deneme1.csv')

# %%
df46.head(50)
# Out:
#     Unnamed: 0                                               Text   Latitude  \
# 0            0  talking to some great journos this morning all...  51.505185
# 1            3  a little snippet from my  sundayjazzcongregati...  51.513451
# 2            4  if you're a  pharmaceutical professional in  m...  53.480759
# 3            5  our 2 day  summit kicks off in our new office ...  51.515238
# 4            7  "  hell yeah! x"\nlook at you      all posh on...  51.430730
# 5            9  2 hours to kill (at london  (lhr) in hounslow,...  51.469715
# 6           12  when life gives you lemon choux with meringue ...  51.513302
# 7           13   egaylity    homophobia in morocco  gay or str...  51.619671
# 8           14   egaylity    homophobia in morocco  gay or str...  51.619671
# 9           30                twin peaks 20 04 16 at rough trade   51.521085
# 10          42  pure's hannah booth  amp  peter horobin at las...  51.526224
# ...

# %%
df46.isnull().sum()
# Out:
# Unnamed: 0    0
# Text          0
# Latitude      0
# Longitude     9
# Country       0
# City          0
# Language      0
# Text_Clean    0
# dtype: int64

# %%
null_data = df46[df46.isnull().any(axis=1)]
null_data
# Out:
#        Unnamed: 0                                               Text  \
# 2660        10519   destinationanywhere after a really long time ...
# 2766        10906  good thing, i had set up twitter with my numbe...
# 7347        27282                                 yeah it was great!
# 7486        27818    shorthair  blonde  selfie  boredatwork  ifee...
# 7749        28700   they were against tamina and naomi  paige and...
# 8565        31924   bettercallsaul come on its been 2 season when...
# 8571        31964   bettercallsaul mike's story is so much better...
# 14016       51976  watch "meg myers   lemon eyes  music video " o...
# 22132       82441  do they still sell ladies jeans unripped at th...
#
#         Latitude  Longitude Country    City Language  \
# 2660   51.495495        NaN      GB  London       en
# 2766   51.495495        NaN      GB  London       en
# 7347   51.549550        NaN      GB  London       en
# 7486   51.513514        NaN      GB  London       en
# ...

# %%
df47 = df46[df46['Longitude'].notna()]

# %%
df47.isnull().sum()
# Out:
# Unnamed: 0    0
# Text          0
# Latitude      0
# Longitude     0
# Country       0
# City          0
# Language      0
# Text_Clean    0
# dtype: int64

# %%
df47.to_csv('twittercleaned.csv')
